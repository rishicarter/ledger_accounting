# %%
# !pip install beyondllm

# %%
# !pip install llama-index-embeddings-huggingface

# %%
# Imports
from beyondllm import source,retrieve,generator,embeddings,llms
from getpass import getpass
from beyondllm.vectordb import ChromaVectorDb

import os

from getpass import getpass
import os

# %%
# AIzaSyDzJpCzonF2U7UQD90LgTWCakM3ay5PpZI - Google
# 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 - HF

hf_token = getpass("Enter HF Token: ")
google_api_key = getpass("Enter Google Token: ")

os.environ['HF_TOKEN'] = hf_token
os.environ['GOOGLE_API_KEY'] = google_api_key

MODEL_NAME = "BAAI/bge-small-en-v1.5"#"thenlper/gte-large"
# Out:
# Enter HF Token: ········
# Enter Google Token: ········

# %%
import pandas as pd

excel_file = 'ledgers.xlsx'
# csv_path = "./data/"

excel_data = pd.ExcelFile(excel_file)
sheet_names = excel_data.sheet_names

for sheet_name in sheet_names:
    df = pd.read_excel(excel_file, sheet_name=sheet_name)
    csv_file_name = f"{sheet_name}.csv"
    df.to_csv(csv_file_name, index=False)

    print(f"Saved {sheet_name} as {csv_file_name}")
# Out:
# Saved Ramesh chowdhary as Ramesh chowdhary.csv
# Saved Pranavni as Pranavni.csv
# Saved hdfc as hdfc.csv

# %%
df = pd.read_csv('hdfc.csv')
# df.head(50)

# %%
index = df[df.iloc[:,0] == 'Date'].index[0]
df1 = df.iloc[index+1:,]

# %%
current_cols = df1.columns
modified_cols = ['date', 'direction', 'transaction_desc', 'vch_type', 'vch_no', 'debit', 'credit']

# %%
df1 = df1.rename(columns=dict(zip(current_cols, modified_cols)))

# %%
df1['transaction_details'] = df1.apply(lambda row: row['transaction_desc'] if pd.isna(row['date']) and pd.isna(row['direction']) else None, axis=1)
df1['transaction_details'] = df1['transaction_details'].bfill()

# %%
df1 = df1[~df1['transaction_desc'].str.contains('Opening Balance|Closing Balance', case=False, na=False)]

# %%
df1.columns
# Out:
# Index(['date', 'direction', 'transaction_desc', 'vch_type', 'vch_no', 'debit',
#        'credit', 'transaction_details'],
#       dtype='object')

# %%
df1 = df1.dropna(subset=['date', 'direction', 'transaction_desc', 'vch_type', 'vch_no'])

# %%
df1.head(50)
# Out:
#                     date direction             transaction_desc vch_type  \
# 7    2024-10-01 00:00:00        By     Festival Events Expenses  Payment
# 9    2024-10-01 00:00:00        To  CHINTAKUNTLA YADAGIRI REDDY  Receipt
# 11   2024-10-02 00:00:00        To             Swipping Machine  Receipt
# 13   2024-10-02 00:00:00        By             Document Charges  Payment
# 15   2024-10-02 00:00:00        By                       Salary  Payment
# 17   2024-10-02 00:00:00        By                       Salary  Payment
# 19   2024-10-02 00:00:00        By                    Ch Balaji  Payment
# 21   2024-10-02 00:00:00        By              Office Expenses  Payment
# 23   2024-10-02 00:00:00        By     Festival Events Expenses  Payment
# 25   2024-10-03 00:00:00        By                 Somarapu Uma  Payment
# 27   2024-10-03 00:00:00        By             Document Charges  Payment
# 29   2024-10-03 00:00:00        By                       Salary  Payment
# 31   2024-10-04 00:00:00        By                    IDBI Bank   Contra
# 33   2024-10-05 00:00:00        To                Plot No. 55 S  Receipt
# 35   2024-10-05 00:00:00        By                    Ch Balaji  Payment
# 37   2024-10-05 00:00:00        To                 Plot Payment  Receipt
# 39   2024-10-07 00:00:00        To                     Suspense  Receipt
# 41   2024-10-07 00:00:00        To             Swipping Machine  Receipt
# 43   2024-10-07 00:00:00        By       Jaanvi Tours & Travels  Payment
# 45   2024-10-07 00:00:00        By                   Jaya Reddy  Payment
# 47   2024-10-07 00:00:00        By              Office Expenses  Payment
# 49   2024-10-08 00:00:00        By                     Suspense  Payment
# 51   2024-10-09 00:00:00        By              Site Allowances  Payment
# 53   2024-10-10 00:00:00        To                 Somarapu Uma  Receipt
# 55   2024-10-10 00:00:00        By                     Suspense  Payment
# 57   2024-10-15 00:00:00        To                     Suspense  Receipt
# 59   2024-10-15 00:00:00        By         Registration Charges  Payment
# 61   2024-10-15 00:00:00        By         Registration Charges  Payment
# 63   2024-10-16 00:00:00        To             Plot No.226 NP S  Receipt
# 65   2024-10-16 00:00:00        To             Plot No.226 NP S  Receipt
# 67   2024-10-16 00:00:00        By             Document Charges  Payment
# 69   2024-10-16 00:00:00        By   Prasad Sir -Ofice Expenses  Payment
# 71   2024-10-16 00:00:00        By                     Ravi Sir  Payment
# 73   2024-10-18 00:00:00        By           Ch Phardha Saradhi  Payment
# 75   2024-10-19 00:00:00        By         Registration Charges  Payment
# 77   2024-10-19 00:00:00        By              Ramesh Chowdary  Payment
# 79   2024-10-19 00:00:00        By              Ramesh Chowdary  Payment
# 81   2024-10-19 00:00:00        By             Document Charges  Payment
# 83   2024-10-20 00:00:00        By              Site Allowances  Payment
# 85   2024-10-21 00:00:00        By                  Jagadrakshi  Payment
# 87   2024-10-21 00:00:00        By                     Donation  Payment
# 89   2024-10-21 00:00:00        By      Silpa Estates & Resorts  Payment
# 91   2024-10-21 00:00:00        By            Peddi Raju-Pardhu  Payment
# 93   2024-10-22 00:00:00        To             Swipping Machine  Receipt
# 95   2024-10-22 00:00:00        By         Registration Charges  Payment
# 97   2024-10-23 00:00:00        To                   ICICI Bank   Contra
# 99   2024-10-23 00:00:00        By             Document Charges  Payment
# 101  2024-10-23 00:00:00        By           Ch Phardha Saradhi  Payment
# 103  2024-10-23 00:00:00        By             Software Renewal  Payment
# 105  2024-10-23 00:00:00        By                  Kapil Chits  Payment
#
#     vch_no    debit   credit  \
# 7     1351      NaN     1200
# 9      624   647000      NaN
# 11     623    11000      NaN
# 13    1352      NaN    26740
# 15    1353      NaN    40000
# 17    1354      NaN    30000
# 19    1356      NaN    50000
# 21    1357      NaN     6000
# 23    1358      NaN     6500
# 25    1359      NaN   458000
# 27    1360      NaN    29500
# 29    1362      NaN    27800
# 31      29      NaN    25000
# 33     628   150000      NaN
# 35    1367      NaN    50000
# 37     633        1      NaN
# 39     631     1070      NaN
# 41     632    50000      NaN
# 43    1369      NaN    50000
# 45    1370      NaN     8000
# 47    1371      NaN     4700
# 49    1380      NaN    70000
# 51    1375      NaN    47350
# 53     641  2000000      NaN
# 55    1381      NaN  2000000
# 57     651   500000      NaN
# 59    1414      NaN  12561.8
# 61    1415      NaN  61761.8
# 63     647   300000      NaN
# 65     648   700000      NaN
# 67    1416      NaN     6000
# 69    1417      NaN   215000
# 71    1418      NaN    95000
# 73    1419      NaN   100000
# 75    1420      NaN   6561.8
# 77    1421      NaN   210000
# 79    1422      NaN    21000
# 81    1423      NaN     3000
# 83    1424      NaN     3000
# 85    1425      NaN   110425
# 87    1426      NaN    85000
# 89    1427      NaN   500000
# 91    1428      NaN    30000
# 93     654   100000      NaN
# 95    1435      NaN  20061.8
# 97      30  1500000      NaN
# 99    1441      NaN     3000
# 101   1442      NaN     2000
# 103   1446      NaN     8850
# 105   1447      NaN    28205
#
#                                    transaction_details
# 7    IMPS-427519367247-ADABALA RAJESH-SBIN-xxxxxxx4...
# 9    RTGS Cr-IBKL0001345-CHINTAKUNTLA YADAGIRI REDD...
# 11                    UPI SETTLEMENT -DDO843- 02-10-24
# 13   IMPS-427610387257-KISHORE IDBI LOAN-IDIB-xxxxx...
# 15   IMPS-427610367916-ADABALA RAJESH-SBIN-xxxxxxx4...
# 17   IMPS-427610386552-DAROJU SWAPNA-HDFC-xxxxxxxxx...
# 19   UPI-chikkam balaji-9144444666@axl-NA-427691536...
# 21   IMPS-427616355694-ADABALA RAJESH-SBIN-xxxxxxx4...
# 23   IMPS-427618391883-ARAVA NAGALINGESWARA PRASAD-...
# 25   IMPS-427709372221-SOMARAPU UMA-UBIN-xxxxxxxxxx...
# 27   IMPS-427711314424-KANNOORI SANDEEP-UTIB-xxxxxx...
# 29   IMPS-427712353693-ANANTULA RAMU-KKBK-xxxxxx531...
# 31                  Chq Paid-MICR CTS-RK-IDBI BANK LTD
# 33   50100524168118-TPT-Plot Purchase-NAMA SREEKANT...
# 35   UPI-chikkam balaji-9144444666@axl-NA-427905689...
# 37              50100524168118-TPT-LAND-NAMA SREEKANTH
# 39   NEFT Cr-SBIN0000TBU-ITDTAX REFUND 2024-25 AFAF...
# 41                    UPI SETTLEMENT -DDO843- 07-10-24
# 43   NEFT Dr-SBIN0020653-CAB DEVARA NAVEEN KUMAR-NE...
# 45   UPI-kurakula sri kanya-9515141600@ibl-NA-42811...
# 47   UPI-kalakonda upendar-9951497147@axl-NA-428112...
# 49   IMPS-428215334628-ARAVA NAGALINGESWARA PRASAD-...
# 51   Being amt transf for silpa site expenses IMPS-...
# 53   RTGS Cr-UBIN0830461-SOMARAPU UMA-SUNSHINE SILP...
# 55   RTGS Dr-YESB0000097-AR INFRA-NAGOLE-HDFCR52024...
# 57   50100098661259-TPT-Self-PYATA CHANDRAKANTH cus...
# 59                  2993790035529-SBIEPYREGSTAMSDEPTTE
# 61                  9576198637513-SBIEPYREGSTAMSDEPTTE
# 63   Chq no. 020684 CHQ DEP - HYDERABAD - MICR - 12...
# 65   Chq no. 020683 CHQ DEP - HYDERABAD - MICR - 12...
# 67   IMPS-429010303202-KANNOORI SANDEEP-UTIB-xxxxxx...
# 69   IMPS-429011334506-ARAVA NAGALINGESWARA PRASAD-...
# 71   IMPS-429014389899-RAVI CHALLA-UTIB-xxxxxxxxxxx...
# 73   IMPS-429215308878-PARDHU-HDFC-xxxxxxxxxx6666-Self
# 75                  7009820120613-SBIEPYREGSTAMSDEPTTE
# 77   IMPS-429311328831-KAPARTHI SANTOSH KUMAR-DCBL-...
# 79   IMPS-429311329938-NANGUNURI RAMESH-CNRB-xxxxxx...
# 81   UPI-mr chandra shekar n-9505189983@ybl-NA-4293...
# 83   IMPS-429414369192-ADABALA RAJESH-SBIN-xxxxxxx4...
# 85   IMPS-429510331719-CHIT FUNDS JAGADRAKSHA-UBIN-...
# 87   IMPS-429510335523-SRI CHALLAPALLIVARI VEDHAPAT...
# 89   IMPS-429510335635-SILPA ESTATES AND RESORTS-UB...
# 91   IMPS-429510339043-BANDI VENKATESWARI-ICIC-xxxx...
# 93                    UPI SETTLEMENT -DDO843- 22-10-24
# 95                  3818249750025-SBIEPYREGSTAMSDEPTTE
# 97   RTGS/ICICR42024102300518099/HDFC0000418/SUNSHI...
# 99   IMPS-429709361123-KANNOORI SANDEEP-UTIB-xxxxxx...
# 101  UPI-suresh n v v s-9052254789@ybl-NA-429770236...
# 103  IMPS-429717353278-N INFO SOLUTIONS-UTIB-xxxxxx...
# 105  IMPS-429716327471-ARAVA NAGALINGESWARA PRASAD-...

# %%
vectordb = ChromaVectorDb(collection_name="my_persistent_collection", persist_directory="./db/chroma/")
# Out:
# The feature you're trying to use requires an additional library(s):llama_index.vector_stores.chroma. Would you like to install it now? [y/N]: y

# %%
csv_paths = ["/content/data/Pranavni.csv", "/content/data/Ramesh chowdhary.csv",
             "/content/data/hdfc.csv"]
# embed_model = embeddings.HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
embed_model = embeddings.GeminiEmbeddings(api_key=google_api_key,
                                          model_name="models/embedding-001")

# %%
data = source.fit(path=csv_paths, dtype="csv")
retriever = retrieve.auto_retriever(
    data=data,
    embed_model=embed_model,
    type="hybrid",
    top_k=5,
    mode="OR")

# %%
llm = llms.GeminiModel(model_name="gemini-pro",
                       google_api_key=google_api_key)

# %%
question="what amount paid to Ramesh Choupardu?"

# %%
system_prompt = """You are an accountant, who answers questions based on the ledgers found in the csvs. 
Each ledger has date, the amount that was debited, type of payment cash or anything else. 
Based on the context answer the quesetion."""

pipeline = generator.Generate(question=question,
                              retriever=retriever,
                              llm=llm,
                              system_prompt=system_prompt)
response = pipeline.call()
response
# Out:
# LLM is explicitly disabled. Using MockLLM.
# Embeddings have been explicitly disabled. Using MockEmbedding.
# '21000'
